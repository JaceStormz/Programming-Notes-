# %%
import numpy as np
blank = np.array([])
blank
# Out:
# array([], dtype=float64)

# %%
type(blank)
# Out:
# numpy.ndarray

# %%
numlist = [30,709,20,-12,35]
print(numlist, type(numlist))
arr1 = np.array(numlist)
print(arr1, type(arr1))
# Out:
# [30, 709, 20, -12, 35] <class 'list'>
# [ 30 709  20 -12  35] <class 'numpy.ndarray'>

# %%
len(arr1)
# Out:
# 5

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1
# Out:
# array([ 30, 709,  20, -12,  35])

# %%
arr1.shape # single dimensional array
# Out:
# (5,)

# %%
arr1.ndim #no. of dimensions
# Out:
# 1

# %%
numlist2 = [[2,3,4],[16,15,28],[45,10,19]]
numlist2
# Out:
# [[2, 3, 4], [16, 15, 28], [45, 10, 19]]

# %%
import numpy as np
arr2 = np.array(numlist2)
arr2
# Out:
# array([[ 2,  3,  4],
#        [16, 15, 28],
#        [45, 10, 19]])

# %%
#no. of items
arr2.size
# Out:
# 9

# %%
new_arr =np.array([[5,18,5,3],[49,17,55,16],[9,19,3,36]])
new_arr
# Out:
# array([[ 5, 18,  5,  3],
#        [49, 17, 55, 16],
#        [ 9, 19,  3, 36]])

# %%
new_arr.shape
# Out:
# (3, 4)

# %%
new_arr.ndim
# Out:
# 2

# %%
new_arr.size
# Out:
# 12

# %%
#reshape an array
new_arr.reshape(3,2,2)
# Out:
# array([[[ 5, 18],
#         [ 5,  3]],
#
#        [[49, 17],
#         [55, 16]],
#
#        [[ 9, 19],
#         [ 3, 36]]])

# %%
new_arr #arrays are not mutable like lists
# Out:
# array([[ 5, 18,  5,  3],
#        [49, 17, 55, 16],
#        [ 9, 19,  3, 36]])
